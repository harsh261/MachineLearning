# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Generate number from -10 to 10 using arange

# %%
X = np.arange(-10,10,1)
y = X**2 # y = x square
z = X**3

# %%
plt.plot(X,y)
plt.show()
plt.plot(X,z)
